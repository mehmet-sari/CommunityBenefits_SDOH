# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz

# read IRS data of 2016 
IRS2016 = pd.read_csv("/home/msari/Project1/Data/IRS_temp_2016.csv", low_memory = False)
print( "This is IRS data shape:", IRS2016.shape)
IRS2016 = IRS2016.rename(columns = {"Filer.EIN" : "EIN"})
print("The unique number of hospitals in IRS for 2016:", len(IRS2016['EIN'].value_counts()))

## read American Hospital Association (AHA) 2016 data to pandas.
AHA = pd.read_csv("/home/msari/Project1/RawData/AHA/2016/FY2016-Annual-Survey-Database/COMMA/ASPUB16.CSV", low_memory = False)
## create a subset of AHA data.
## now let's create an id data for AHA consisting of only id variables for providers
id_variables = ['ID', 'NPINUM', 'MCRNUM', 'MNAME','SYSNAME', 'SYSID', 'STCD', 'DTBEG', 'DTEND', 'FISYR', 'SERV', 'HSACODE', 'HSANAME', 'HRRNAME', 'HRRCODE', 'MLOCADDR', 'MLOCCITY', 'MLOCSTD', 'MLOCZIP' ,'SYSADDR' ,'SYSCITY' ,'SYSST' ,'SYSZIP' ,'SYSAREA' ,'SYSTELN' ,'SYSTEM_PRIMARY_CONTACT' ,'SYSTITLE' ,'LAT' ,'LONG' ,'CNTYNAME' ,'CBSANAME' ,'CBSATYPE' ,'CBSACODE' ,'DIVNAME' ,'DIVCODE' ,'CSANAME' ,'CSACODE' ,'MCNTYCD' ,'FCOUNTY' ,'FSTCD' ,'FCNTYCD', 'CNTRL']
aha2016 = AHA.loc[:, id_variables]
print( "This is AHA data shape:", aha2016.shape)
print("The unique number of hospitals in AHA for 2016:", len(aha2016['ID'].value_counts()))
# Out:
# This is IRS data shape: (2666, 420)
# The unique number of hospitals in IRS for 2016: 2349
# This is AHA data shape: (6239, 42)
# The unique number of hospitals in AHA for 2016: 6239
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
bins = [0, 20, 30, 40, np.inf]
names = [ 'Government-NonFederal', 'non-profit', 'for-profit', 'Government-Federal']
aha2016['ControlCode'] = pd.cut(aha2016['CNTRL'], bins, labels=names)
aha2016['ControlCode'].value_counts()
# Out:
# non-profit               3107
# for-profit               1690
# Government-NonFederal    1228
# Government-Federal        214
# Name: ControlCode, dtype: int64

# %% [markdown]
# IRS data includes only non-profit hospitals or hospital systems, however, AHA data includes non-profit, for-profit and government (public) hospitals. There is no key identifier to match these two datasets. I need to use name, address, zipcode, city, and state columns to fuzzy-match those hospitals that are in both datasets. Key identifier in IRS is EIN, the key Identifier in AHA is ID variable.
#
# I will match two datasets based on aha2016['address'] and IRS2016['address'] which are created by combining street address, city, state and zipcode columns in each dataset.
#
# *Problem*:
#
#     -how to add name column to matching code?
#     -how to add key identifiers to matching table so it can be merged with other variables?

# %%
# little manipulation for better matching (uppercase) and renaming variables to make it readable. 

# uppercase
IRS2016['Filer.USAddress.CityNm'] = IRS2016['Filer.USAddress.CityNm'].str.upper()
aha2016.SYSCITY = aha2016.SYSCITY.str.upper()
IRS2016['Filer.USAddress.AddressLine1Txt'] = IRS2016['Filer.USAddress.AddressLine1Txt'].str.upper()
aha2016['SYSADDR'] = aha2016['SYSADDR'].str.upper()

# renaming columns in IRS
IRS2016.rename(columns={'Filer.USAddress.CityNm' : 'SYSCITY', 'Filer.USAddress.StateAbbreviationCd': 'STATE', 'Filer.USAddress.AddressLine1Txt': 'ADDRESS'}, inplace=True)

## zipcode columns is not clean some are more than 5 digits.
d = []
for n in IRS2016['Filer.USAddress.ZIPCd']:
    d.append(str(n)[:5])
    
IRS2016['zipcode'] = pd.DataFrame(d)

L = []
for n in aha2016['SYSZIP']:
    L.append(str(n)[:5])
aha2016['zipcode'] = pd.DataFrame(L)

# I create a new address column that combines street address, city, state and zipcode for fuzzymatching.
aha2016['address'] = aha2016['SYSADDR'].str.cat(aha2016[['SYSCITY', 'SYSST', 'zipcode']], sep=' , ')
IRS2016['address'] =  IRS2016['ADDRESS'].str.cat(IRS2016[['SYSCITY', 'STATE', 'zipcode']], sep = ' , ')

# %%
## Here I am using address column that I created above to match two datasets.

def match_name(name, list_names, min_score=0):
    # -1 score incase no matches
    max_score = -1
    # Returning empty name for no match as well
    max_name = ""
    # Iternating over all names in the other
    for name2 in list_names:
        #Finding fuzzy match score
        score = fuzz.token_sort_ratio(name, name2)
        # Checking if we are above our threshold and have a better score
        if (score > min_score) & (score > max_score):
            max_name = name2
            max_score = score
    return (max_name, max_score)

# List for dicts for easy dataframe creation
dict_list = []
# iterating over our addresses without any further info
for address in aha2016['address']:
    # Use the method to find best match, I can set a threshold here
    match = match_name(address, IRS2016['address'], 75)
    # New dict for storing data
    dict_ = {}
    dict_.update({"AHA_adress" : address})
    dict_.update({"IRS_address" : match[0]})
    dict_.update({"score" : match[1]})
    dict_list.append(dict_)
    
merge_table1 = pd.DataFrame(dict_list)
merge_table1
# Out:
#                                              AHA_adress  \
# 0        5109 LEESBURG PIKE , FALLS CHURCH , VA , 22041
# 1                                                   NaN
# 2             603 MAIN STREET , WINDERMERE , FL , 34786
# 3                                                   NaN
# 4                                                   NaN
# 5     BUILDING 'A' - MEDICAL CENTER , SAN JUAN , PR ...
# 6                                                   NaN
# 7                                                   NaN
# 8     3660 GRANDVIEW PARKWAY, SUITE 200 , BIRMINGHAM...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13    BUILDING 'A' - MEDICAL CENTER , SAN JUAN , PR ...
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21    3660 GRANDVIEW PARKWAY, SUITE 200 , BIRMINGHAM...
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6209                                                NaN
# 6210                                                NaN
# 6211         55 MERCHANT STREET , HONOLULU , HI , 96813
# 6212      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813
# 6213        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6214        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6215        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6216        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6217        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6218        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6219         55 MERCHANT STREET , HONOLULU , HI , 96813
# 6220        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6221            ONE KAISER PLAZA , OAKLAND , CA , 94612
# 6222            ONE KAISER PLAZA , OAKLAND , CA , 94612
# 6223            ONE KAISER PLAZA , OAKLAND , CA , 94612
# 6224      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813
# 6225   2200 RIVER PLAZA DRIVE , SACRAMENTO , CA , 95833
# 6226            ONE KAISER PLAZA , OAKLAND , CA , 94612
# 6227         55 MERCHANT STREET , HONOLULU , HI , 96813
# 6228                                                NaN
# 6229                                                NaN
# 6230        3675 KILAUEA AVENUE , HONOLULU , HI , 96816
# 6231      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813
# 6232        2900 ROCKY POINT DRIVE , TAMPA , FL , 33607
# 6233         55 MERCHANT STREET , HONOLULU , HI , 96813
# 6234     5109 LEESBURG PIKE , FALLS CHURCH , VA , 22041
# 6235                                                NaN
# 6236    2100 DOUGLAS BOULEVARD , ROSEVILLE , CA , 95661
# 6237                                                NaN
# 6238                                                NaN
#
#                                             IRS_address  score
# 0                                                           -1
# 1                                                   NaN    100
# 2                                                           -1
# 3                                                   NaN    100
# 4                                                   NaN    100
# 5                                                           -1
# 6                                                   NaN    100
# 7                                                   NaN    100
# 8                                                           -1
# 9                                                   NaN    100
# 10                                                  NaN    100
# 11                                                  NaN    100
# 12                                                  NaN    100
# 13                                                          -1
# 14                                                  NaN    100
# 15                                                  NaN    100
# 16                                                  NaN    100
# 17                                                  NaN    100
# 18                                                  NaN    100
# 19                                                  NaN    100
# 20                                                  NaN    100
# 21                                                          -1
# 22                                                  NaN    100
# 23                                                  NaN    100
# 24                                                  NaN    100
# 25                                                  NaN    100
# 26                                                  NaN    100
# 27                                                  NaN    100
# 28                                                  NaN    100
# 29                                                  NaN    100
# ...                                                 ...    ...
# 6209                                                NaN    100
# 6210                                                NaN    100
# 6211  55 MERCHANT STREET 24TH FLOOR , HONOLULU , HI ...     87
# 6212      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813    100
# 6213                                                        -1
# 6214                                                        -1
# 6215                                                        -1
# 6216                                                        -1
# 6217                                                        -1
# 6218                                                        -1
# 6219  55 MERCHANT STREET 24TH FLOOR , HONOLULU , HI ...     87
# 6220                                                        -1
# 6221        ONE KAISER PLAZA 15L , OAKLAND , CA , 94612     94
# 6222        ONE KAISER PLAZA 15L , OAKLAND , CA , 94612     94
# 6223        ONE KAISER PLAZA 15L , OAKLAND , CA , 94612     94
# 6224      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813    100
# 6225   2200 RIVER PLAZA DRIVE , SACRAMENTO , CA , 95833    100
# 6226        ONE KAISER PLAZA 15L , OAKLAND , CA , 94612     94
# 6227  55 MERCHANT STREET 24TH FLOOR , HONOLULU , HI ...     87
# 6228                                                NaN    100
# 6229                                                NaN    100
# 6230                                                        -1
# 6231      1301 PUNCHBOWL STREET , HONOLULU , HI , 96813    100
# 6232                                                        -1
# 6233  55 MERCHANT STREET 24TH FLOOR , HONOLULU , HI ...     87
# 6234                                                        -1
# 6235                                                NaN    100
# 6236                                                        -1
# 6237                                                NaN    100
# 6238                                                NaN    100
#
# [6239 rows x 3 columns]

# %%
## Matching function somehow matches NaNs and could not locate the problem. Here I am dropping those matches.
merge_table_upd = merge_table1.dropna()
merge_table_upd.sort_values(by=['score'], ascending=False)
# Out:
#                                              AHA_adress  \
# 2922         1905 AMERICAN WAY , KINGSPORT , TN , 37660
# 1528             1350 WALTON WAY , AUGUSTA , GA , 30901
# 1537  1601 WATSON BOULEVARD , WARNER ROBINS , GA , 3...
# 1542  1601 WATSON BOULEVARD , WARNER ROBINS , GA , 3...
# 1544        35 HOSPITAL ROAD , BLAIRSVILLE , GA , 30512
# 1549        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 1554      600 EAST DIXIE AVENUE , LEESBURG , FL , 34748
# 1555      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 1556        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 5175        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 1570      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 1574        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 1578      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 1587        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 5152        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 1594      300 PINELLAS STREET , CLEARWATER , FL , 33756
# 1599      600 EAST DIXIE AVENUE , LEESBURG , FL , 34748
# 5097  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405
# 1613      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 5085  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405
# 5081      915 HIGHLAND BOULEVARD , BOZEMAN , MT , 59715
# 5071  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405
# 5070       919 HIDDEN RIDGE DRIVE , IRVING , TX , 75038
# 1630        20555 VICTOR PARKWAY , LIVONIA , MI , 48152
# 1631      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 1534         705 DIXIE STREET , CARROLLTON , GA , 30117
# 1511            793 SAWYER ROAD , MARIETTA , GA , 30062
# 1635      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714
# 5219           106 BLANCA AVENUE , ALAMOSA , CO , 81101
# 1405            793 SAWYER ROAD , MARIETTA , GA , 30062
# ...                                                 ...
# 2391  319 EAST MADISON STREET, S-3B , SPRINGFIELD , ...
# 2393            1202 PAGE DRIVE SW , FARGO , ND , 58103
# 2396  680 SOUTH FOURTH STREET , LOUISVILLE , KY , 40202
# 2399  2650 EASTPOINT PARKWAY, SUITE 300 , LOUISVILLE...
# 2340   385 MILLENNIUM DRIVE , CRYSTAL LAKE , IL , 60012
# 2324  101 SOUTH HANLEY ROAD, SUITE 450 , SAINT LOUIS...
# 2241  367 SOUTH GULPH ROAD , KING OF PRUSSIA , PA , ...
# 2320    810 VERMONT AVENUE NW , WASHINGTON , DC , 20420
# 2244  319 EAST MADISON STREET, S-3B , SPRINGFIELD , ...
# 2247  1900 WEST POLK STREET, SUITE 220 , CHICAGO , I...
# 2248        4238 GREEN RIVER ROAD , CORONA , CA , 92880
# 2254  1445 ROSS AVENUE, SUITE 1400 , DALLAS , TX , 7...
# 2260  1653 WEST CONGRESS PARKWAY , CHICAGO , IL , 60612
# 2261  1900 WEST POLK STREET, SUITE 220 , CHICAGO , I...
# 2265  367 SOUTH GULPH ROAD , KING OF PRUSSIA , PA , ...
# 2271        2900 ROCKY POINT DRIVE , TAMPA , FL , 33607
# 2278    810 VERMONT AVENUE NW , WASHINGTON , DC , 20420
# 2285    810 VERMONT AVENUE NW , WASHINGTON , DC , 20420
# 2291  319 EAST MADISON STREET, S-3B , SPRINGFIELD , ...
# 2294  101 SOUTH HANLEY ROAD, SUITE 450 , SAINT LOUIS...
# 2298  9350 SOUTH CALIFORNIA AVENUE , EVERGREEN PARK ...
# 2301  367 SOUTH GULPH ROAD , KING OF PRUSSIA , PA , ...
# 2304  1573 MALLORY LANE, SUITE 100 , BRENTWOOD , TN ...
# 2306  5110 MARYLAND WAY SUITE 200 , BRENTWOOD , TN ,...
# 2308  2650 EASTPOINT PARKWAY, SUITE 300 , LOUISVILLE...
# 2310  1573 MALLORY LANE, SUITE 100 , BRENTWOOD , TN ...
# 2313  1000 MINERAL POINT AVENUE , JANESVILLE , WI , ...
# 2317    1239 EAST MAIN STREET , CARBONDALE , IL , 62901
# 2319  5110 MARYLAND WAY SUITE 200 , BRENTWOOD , TN ,...
# 6236    2100 DOUGLAS BOULEVARD , ROSEVILLE , CA , 95661
#
#                                             IRS_address  score
# 2922         1905 AMERICAN WAY , KINGSPORT , TN , 37660    100
# 1528             1350 WALTON WAY , AUGUSTA , GA , 30901    100
# 1537  1601 WATSON BOULEVARD , WARNER ROBINS , GA , 3...    100
# 1542  1601 WATSON BOULEVARD , WARNER ROBINS , GA , 3...    100
# 1544        35 HOSPITAL ROAD , BLAIRSVILLE , GA , 30512    100
# 1549        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 1554      600 EAST DIXIE AVENUE , LEESBURG , FL , 34748    100
# 1555      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 1556        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 5175        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 1570      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 1574        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 1578      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 1587        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 5152        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 1594      300 PINELLAS STREET , CLEARWATER , FL , 33756    100
# 1599      600 EAST DIXIE AVENUE , LEESBURG , FL , 34748    100
# 5097  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405    100
# 1613      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 5085  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405    100
# 5081      915 HIGHLAND BOULEVARD , BOZEMAN , MT , 59715    100
# 5071  1101 26TH STREET SOUTH , GREAT FALLS , MT , 59405    100
# 5070       919 HIDDEN RIDGE DRIVE , IRVING , TX , 75038    100
# 1630        20555 VICTOR PARKWAY , LIVONIA , MI , 48152    100
# 1631      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 1534         705 DIXIE STREET , CARROLLTON , GA , 30117    100
# 1511            793 SAWYER ROAD , MARIETTA , GA , 30062    100
# 1635      900 HOPE WAY , ALTAMONTE SPRINGS , FL , 32714    100
# 5219           106 BLANCA AVENUE , ALAMOSA , CO , 81101    100
# 1405            793 SAWYER ROAD , MARIETTA , GA , 30062    100
# ...                                                 ...    ...
# 2391                                                        -1
# 2393                                                        -1
# 2396                                                        -1
# 2399                                                        -1
# 2340                                                        -1
# 2324                                                        -1
# 2241                                                        -1
# 2320                                                        -1
# 2244                                                        -1
# 2247                                                        -1
# 2248                                                        -1
# 2254                                                        -1
# 2260                                                        -1
# 2261                                                        -1
# 2265                                                        -1
# 2271                                                        -1
# 2278                                                        -1
# 2285                                                        -1
# 2291                                                        -1
# 2294                                                        -1
# 2298                                                        -1
# 2301                                                        -1
# 2304                                                        -1
# 2306                                                        -1
# 2308                                                        -1
# 2310                                                        -1
# 2313                                                        -1
# 2317                                                        -1
# 2319                                                        -1
# 6236                                                        -1
#
# [4056 rows x 3 columns]

# %%
merge_table_upd['score'].value_counts()
# Out:
# -1      2746
#  100     550
#  90      130
#  89       89
#  96       72
#  94       62
#  88       62
#  85       44
#  81       33
#  80       32
#  83       32
#  95       32
#  91       27
#  77       22
#  82       21
#  97       20
#  87       17
#  93       15
#  92       11
#  98       10
#  76       10
#  78        9
#  79        7
#  84        3
# Name: score, dtype: int64

# %%
IRS2016.to_csv("IRS2016.csv")
aha2016.to_csv("aha2016.csv")
merge_table_upd.to_csv("merge_table_upd.to_csv")
